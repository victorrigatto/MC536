# %% [markdown]
# # Tarefa 1

# %%
import io
import pandas as pd
url = "https://data.cdc.gov/resource/vc9m-u7tv.json"
data = pd.read_json(url)
df = pd.DataFrame(data)
print (df)
# Out:
#      year         sex age_group_years       race injury_mechanism  \
# 0    2016  Both sexes        All Ages  All races   All Mechanisms
# 1    2015  Both sexes        All Ages  All races   All Mechanisms
# 2    2014  Both sexes        All Ages  All races   All Mechanisms
# 3    2013  Both sexes        All Ages  All races   All Mechanisms
# 4    2012  Both sexes        All Ages  All races   All Mechanisms
# ..    ...         ...             ...        ...              ...
# 995  1999        Male           65–74   Hispanic   All Mechanisms
# 996  2016        Male             75+   Hispanic   All Mechanisms
# 997  2015        Male             75+   Hispanic   All Mechanisms
# 998  2014        Male             75+   Hispanic   All Mechanisms
# 999  2013        Male             75+   Hispanic   All Mechanisms
#
#       injury_intent  deaths  population  age_specific_rate  \
# 0    All Intentions  231991   323127513          71.795496
# 1    All Intentions  214008   321418820          66.582287
# 2    All Intentions  199752   318857056          62.646254
# 3    All Intentions  192945   316128839          61.033660
# 4    All Intentions  190385   313914040          60.648769
# ..              ...     ...         ...                ...
# 995  All Intentions     380      455199          83.479972
# 996  All Intentions     951      626922         151.693510
# 997  All Intentions     923      599905         153.857690
# 998  All Intentions     864      567073         152.361340
# 999  All Intentions     827      533791         154.929550
#
#      age_specific_rate_standard_error  \
# 0                            0.149060
# 1                            0.143928
# 2                            0.140168
# 3                            0.138948
# 4                            0.138997
# ..                                ...
# 995                          4.282432
# 996                          4.918999
# 997                          5.064288
# 998                          5.183438
# 999                          5.387428
#
#      age_specific_rate_lower_confidence_limit  \
# 0                                   71.503338
# 1                                   66.300189
# 2                                   62.371524
# 3                                   60.761321
# 4                                   60.376334
# ..                                        ...
# 995                                 75.086405
# 996                                142.052270
# 997                                143.931690
# 998                                142.201800
# 999                                144.370190
#
#      age_specific_rate_upper_confidence_limit age_adjusted_rate  \
# 0                                   72.087654         68.982236
# 1                                   66.864384         63.866114
# 2                                   62.920983         60.127242
# 3                                   61.305998         58.771709
# 4                                   60.921203         58.696255
# ..                                        ...               ...
# 995                                 91.873540
# 996                                161.334750
# 997                                163.783700
# 998                                162.520870
# 999                                165.488910
#
#     age_adjusted_rate_standard_error age_adjusted_rate_lower_confidence_limit  \
# 0                          0.1460097                                68.696057
# 1                           0.140507                                 63.59072
# 2                           0.136713                                59.859285
# 3                          0.1357892                                58.505562
# 4                          0.1362913                                58.429124
# ..                               ...                                      ...
# 995
# 996
# 997
# 998
# 999
#
#     age_adjusted_rate_upper_confidence_limit
# 0                                  69.268415
# 1                                  64.141508
# 2                                    60.3952
# 3                                  59.037856
# 4                                  58.963386
# ..                                       ...
# 995
# 996
# 997
# 998
# 999
#
# [1000 rows x 16 columns]

# %%
import pandas as pd
import io
import requests
url = "https://data.cdc.gov/resource/vc9m-u7tv.csv"
data = requests.get(url).content
csv = pd.read_csv(io.StringIO(data.decode("utf-8")))
print(csv)
# Out:
#      year         sex age_group_years       race injury_mechanism  \
# 0    2016  Both sexes        All Ages  All races   All Mechanisms
# 1    2015  Both sexes        All Ages  All races   All Mechanisms
# 2    2014  Both sexes        All Ages  All races   All Mechanisms
# 3    2013  Both sexes        All Ages  All races   All Mechanisms
# 4    2012  Both sexes        All Ages  All races   All Mechanisms
# ..    ...         ...             ...        ...              ...
# 995  1999        Male           65–74   Hispanic   All Mechanisms
# 996  2016        Male             75+   Hispanic   All Mechanisms
# 997  2015        Male             75+   Hispanic   All Mechanisms
# 998  2014        Male             75+   Hispanic   All Mechanisms
# 999  2013        Male             75+   Hispanic   All Mechanisms
#
#       injury_intent  deaths  population  age_specific_rate  \
# 0    All Intentions  231991   323127513          71.795496
# 1    All Intentions  214008   321418820          66.582287
# 2    All Intentions  199752   318857056          62.646254
# 3    All Intentions  192945   316128839          61.033660
# 4    All Intentions  190385   313914040          60.648769
# ..              ...     ...         ...                ...
# 995  All Intentions     380      455199          83.479972
# 996  All Intentions     951      626922         151.693510
# 997  All Intentions     923      599905         153.857690
# 998  All Intentions     864      567073         152.361340
# 999  All Intentions     827      533791         154.929550
#
#      age_specific_rate_standard_error  \
# 0                            0.149060
# 1                            0.143928
# 2                            0.140168
# 3                            0.138948
# 4                            0.138997
# ..                                ...
# 995                          4.282432
# 996                          4.918999
# 997                          5.064288
# 998                          5.183438
# 999                          5.387428
#
#      age_specific_rate_lower_confidence_limit  \
# 0                                   71.503338
# 1                                   66.300189
# 2                                   62.371524
# 3                                   60.761321
# 4                                   60.376334
# ..                                        ...
# 995                                 75.086405
# 996                                142.052270
# 997                                143.931690
# 998                                142.201800
# 999                                144.370190
#
#      age_specific_rate_upper_confidence_limit age_adjusted_rate  \
# 0                                   72.087654         68.982236
# 1                                   66.864384         63.866114
# 2                                   62.920983         60.127242
# 3                                   61.305998         58.771709
# 4                                   60.921203         58.696255
# ..                                        ...               ...
# 995                                 91.873540
# 996                                161.334750
# 997                                163.783700
# 998                                162.520870
# 999                                165.488910
#
#     age_adjusted_rate_standard_error age_adjusted_rate_lower_confidence_limit  \
# 0                          0.1460097                                68.696057
# 1                           0.140507                                 63.59072
# 2                           0.136713                                59.859285
# 3                          0.1357892                                58.505562
# 4                          0.1362913                                58.429124
# ..                               ...                                      ...
# 995
# 996
# 997
# 998
# 999
#
#     age_adjusted_rate_upper_confidence_limit
# 0                                  69.268415
# 1                                  64.141508
# 2                                    60.3952
# 3                                  59.037856
# 4                                  58.963386
# ..                                       ...
# 995
# 996
# 997
# 998
# 999
#
# [1000 rows x 16 columns]

# %% [markdown]
# # Tarefa 2
